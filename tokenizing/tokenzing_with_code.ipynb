# %% [markdown]
# ## Tokenizing with code

# %%
import tiktoken

encoding = tiktoken.get_encoding("cl100k_base")

# %%
tokens = encoding.encode("Hi! My name is Pradeep Kumar and I like AI")

tokens
# Out:
# [13347, 0, 3092, 836, 374, 2394, 1037, 752, 41240, 323, 358, 1093, 15592]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 13347 = Hi
# 0 = !
# 3092 =  My
# 836 =  name
# 374 =  is
# 2394 =  Pr
# 1037 = ade
# 752 = ep
# 41240 =  Kumar
# 323 =  and
# 358 =  I
# 1093 =  like
# 15592 =  AI

# %%
encoding.decode([41240])
# Out:
# ' Kumar'
